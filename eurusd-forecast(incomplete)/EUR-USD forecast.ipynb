# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('EURUSD=X.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume
# 0  2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186     0.0
# 1  2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122     0.0
# 2  2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723     0.0
# 3  2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474     0.0
# 4  2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396     0.0

# %%
df.tail()
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 1300  2022-11-14  1.032855  1.035025  1.027359  1.032855   1.032855     0.0
# 1301  2022-11-15  1.031928  1.047548  1.031385  1.031928   1.031928     0.0
# 1302  2022-11-16  1.035786  1.043732  1.033645  1.035786   1.035786     0.0
# 1303  2022-11-17  1.039501  1.040572  1.030949  1.039501   1.039501     0.0
# 1304  2022-11-18  1.036592  1.039609  1.033165  1.035090   1.035090     0.0

# %%
#note that saturday and monday is excluded. That is why we have 1304 days of data.
df.set_index('Date', inplace = True)

# %%
df['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.shape
# Out:
# (1305, 6)

# %%
df.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.shape
# Out:
# (1304, 6)

# %%
data = df.copy()

# %%
data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186     0.0
# 2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122     0.0
# 2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723     0.0
# 2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474     0.0
# 2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396     0.0

# %%
df.loc[~(df==0).all(axis=1)]
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186     0.0
# 2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122     0.0
# 2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723     0.0
# 2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474     0.0
# 2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396     0.0
# ...              ...       ...       ...       ...        ...     ...
# 2022-11-14  1.032855  1.035025  1.027359  1.032855   1.032855     0.0
# 2022-11-15  1.031928  1.047548  1.031385  1.031928   1.031928     0.0
# 2022-11-16  1.035786  1.043732  1.033645  1.035786   1.035786     0.0
# 2022-11-17  1.039501  1.040572  1.030949  1.039501   1.039501     0.0
# 2022-11-18  1.036592  1.039609  1.033165  1.035090   1.035090     0.0
#
# [1304 rows x 6 columns]

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186     0.0
# 2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122     0.0
# 2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723     0.0
# 2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474     0.0
# 2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396     0.0

# %%
df = df.replace(0, np.nan)
df = df.dropna(how='all', axis=0)
df = df.replace(np.nan, 0)

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186     0.0
# 2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122     0.0
# 2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723     0.0
# 2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474     0.0
# 2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396     0.0

# %%
df = df.replace(0, np.nan)

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186     NaN
# 2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122     NaN
# 2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723     NaN
# 2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474     NaN
# 2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396     NaN

# %%
df = df.dropna(how='all', axis=1)

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186   1.173186
# 2017-11-21  1.173874  1.175668  1.171550  1.174122   1.174122
# 2017-11-22  1.174095  1.179816  1.173557  1.173723   1.173723
# 2017-11-23  1.181516  1.185500  1.181447  1.181474   1.181474
# 2017-11-24  1.185087  1.194372  1.183726  1.185396   1.185396

# %%
df.tail()
# Out:
#                 Open      High       Low     Close  Adj Close
# Date
# 2022-11-14  1.032855  1.035025  1.027359  1.032855   1.032855
# 2022-11-15  1.031928  1.047548  1.031385  1.031928   1.031928
# 2022-11-16  1.035786  1.043732  1.033645  1.035786   1.035786
# 2022-11-17  1.039501  1.040572  1.030949  1.039501   1.039501
# 2022-11-18  1.036592  1.039609  1.033165  1.035090   1.035090

# %%
data = df.copy()

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close
# count  1304.000000  1304.000000  1304.000000  1304.000000  1304.000000
# mean      1.139042     1.142400     1.135567     1.139073     1.139073
# std       0.059191     0.058851     0.059566     0.059197     0.059197
# min       0.959619     0.967006     0.954016     0.959619     0.959619
# 25%       1.108522     1.110833     1.106461     1.108552     1.108552
# 50%       1.137488     1.141084     1.134900     1.137514     1.137514
# 75%       1.181897     1.184813     1.178505     1.181785     1.181785
# max       1.251267     1.255808     1.245051     1.251001     1.251001

# %%
#we can see close and adj close is generating the same output. we will use Close data and drop the Adj close.
df.drop('Adj Close', inplace=True, axis=1)
data.drop('Adj Close', inplace=True, axis=1)

# %%
df.head()
# Out:
#                 Open      High       Low     Close
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186
# 2017-11-21  1.173874  1.175668  1.171550  1.174122
# 2017-11-22  1.174095  1.179816  1.173557  1.173723
# 2017-11-23  1.181516  1.185500  1.181447  1.181474
# 2017-11-24  1.185087  1.194372  1.183726  1.185396

# %%
data.head()
# Out:
#                 Open      High       Low     Close
# Date
# 2017-11-20  1.173213  1.180749  1.172594  1.173186
# 2017-11-21  1.173874  1.175668  1.171550  1.174122
# 2017-11-22  1.174095  1.179816  1.173557  1.173723
# 2017-11-23  1.181516  1.185500  1.181447  1.181474
# 2017-11-24  1.185087  1.194372  1.183726  1.185396

# %%
df.describe()
# Out:
#               Open         High          Low        Close
# count  1304.000000  1304.000000  1304.000000  1304.000000
# mean      1.139042     1.142400     1.135567     1.139073
# std       0.059191     0.058851     0.059566     0.059197
# min       0.959619     0.967006     0.954016     0.959619
# 25%       1.108522     1.110833     1.106461     1.108552
# 50%       1.137488     1.141084     1.134900     1.137514
# 75%       1.181897     1.184813     1.178505     1.181785
# max       1.251267     1.255808     1.245051     1.251001

# %%
df.tail()
# Out:
#                 Open      High       Low     Close
# Date
# 2022-11-14  1.032855  1.035025  1.027359  1.032855
# 2022-11-15  1.031928  1.047548  1.031385  1.031928
# 2022-11-16  1.035786  1.043732  1.033645  1.035786
# 2022-11-17  1.039501  1.040572  1.030949  1.039501
# 2022-11-18  1.036592  1.039609  1.033165  1.035090

# %%
#this will be the dataset for predicting the EURUSD parity.
